# %%
# -*- coding: utf-8 -*-
"""
================================================================================
EfficientNet-B3 Model + Training for Binary DR Detection (TWO-STAGE FINE-TUNING)
================================================================================

Two-Stage Training:
- Phase 1: Freeze backbone, train only classifier (faster convergence)
- Phase 2: Unfreeze backbone, fine-tune entire model (better final performance)

Model: EfficientNet-B3 @ 300x300 resolution
Uses cached preprocessed images from previous pipeline.

NaN-Safe Version: Automatically skips batches containing NaN values

Author: [Your Name]
Date: 2025
================================================================================
"""

# ============================================================
# 1. Imports & Config
# ============================================================

import os
import random
import numpy as np
import pandas as pd
import cv2
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, GradScaler
from torchvision import models, transforms
from sklearn.metrics import (
    accuracy_score, roc_auc_score,
    precision_score, recall_score,
    f1_score, confusion_matrix,
    classification_report, roc_curve,
    precision_recall_curve, average_precision_score
)
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import time
import copy
import warnings

warnings.filterwarnings('ignore')

print("=" * 70)
print("RETINAL CNN TRAINING PIPELINE (EfficientNet-B3 @ 300)")
print("=" * 70)


# ============================================================
# 2. Configuration
# ============================================================

class Config:
    """Data configuration."""
    DATA_DIR = "/content/drive/MyDrive/MULTIMODAL/datasets/EYEPACS/images/resized_train_cropped"
    SPLITS_DIR = "/content/drive/MyDrive/MULTIMODAL/datasets/EYEPACS/splits"

    # ─────────────────────────────────────────────────────────
    # CHANGED: Separate cache directory for B3 @ 300x300
    # ─────────────────────────────────────────────────────────
    CACHE_DIR = "/content/drive/MyDrive/MULTIMODAL/datasets/EYEPACS/preprocessed_cache_300"

    # ─────────────────────────────────────────────────────────
    # CHANGED: Image size to 300 (B3 native resolution)
    # ─────────────────────────────────────────────────────────
    IMAGE_SIZE = 300

    # ─────────────────────────────────────────────────────────
    # CHANGED: Reduced batch size for larger model + images
    # ─────────────────────────────────────────────────────────
    BATCH_SIZE = 8

    NUM_WORKERS = 2
    SEED = 42


class ModelConfig:
    """Model and training configuration."""

    # ─────────────────────────────────────────────────────────
    # CHANGED: EfficientNet-B3
    # ─────────────────────────────────────────────────────────
    MODEL_NAME = 'efficientnet_b3'

    PRETRAINED = True
    NUM_EPOCHS = 40
    LR = 1e-4
    WEIGHT_DECAY = 1e-5
    DROPOUT = 0.3
    POS_WEIGHT = 2.0
    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # ─────────────────────────────────────────────────────────
    # CHANGED: Separate save directory for B3 outputs
    # ─────────────────────────────────────────────────────────
    SAVE_DIR = "/content/drive/MyDrive/MULTIMODAL/models/efficientnet_b3_experiment"
    MODEL_SAVE_NAME = "efficientnet_b3_binary_dr_twostage.pth"

    # ─────────────────────────────────────────────────────────
    # CHANGED: Separate figures directory
    # ─────────────────────────────────────────────────────────
    FIGURES_DIR = "/content/drive/MyDrive/MULTIMODAL/models/efficientnet_b3_experiment/figures"

    # Preprocessing options (must match cache)
    USE_BEN_GRAHAM = True
    USE_CLAHE = False
    USE_CIRCLE_CROP = True

    # Optimization options
    USE_MIXED_PRECISION = True
    USE_CACHED_IMAGES = True

    # Early stopping
    EARLY_STOPPING_PATIENCE = 7
    EARLY_STOPPING_MIN_DELTA = 0.001

    # Two-Stage Fine-Tuning Parameters
    FREEZE_EPOCHS = 5
    UNFREEZE_LR_FACTOR = 0.5
    FREEZE_BN = False


def seed_everything(seed: int = 42):
    """Set random seeds for reproducibility."""
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"[INFO] Random seed set to {seed}")


# ============================================================
# 3. Image Preprocessing Functions (for caching)
# ============================================================

def crop_black(img, tolerance=7):
    """Remove black borders from fundus image."""
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    mask = gray > tolerance
    coords = np.argwhere(mask)
    if coords.size == 0:
        return img
    y0, x0 = coords.min(0)
    y1, x1 = coords.max(0)
    return img[y0:y1+1, x0:x1+1]


def apply_clahe(img, clip_limit=2.0, tile_grid_size=(8, 8)):
    """Apply CLAHE enhancement to image."""
    lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
    lab[:, :, 0] = clahe.apply(lab[:, :, 0])
    return cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)


def circle_crop(img):
    """Apply circular mask to remove corners."""
    h, w = img.shape[:2]
    r = min(h, w) // 2
    mask = np.zeros((h, w), np.uint8)
    cv2.circle(mask, (w // 2, h // 2), r, 255, -1)
    return cv2.bitwise_and(img, img, mask=mask)


def preprocess_image_for_cache(path, image_size=300,
                                use_clahe=False,
                                use_circle_crop=True,
                                use_ben_graham=True):
    """Preprocess image and return numpy array for caching."""
    img = cv2.imread(path)
    if img is None:
        return None
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = crop_black(img)

    # ─────────────────────────────────────────────────────────
    # CHANGED: Adjusted base_size for 300
    # ─────────────────────────────────────────────────────────
    base_size = max(image_size, 320)
    img = cv2.resize(img, (base_size, base_size))

    if use_ben_graham:
        blur = cv2.GaussianBlur(img, (0, 0), 10)
        img = cv2.addWeighted(img, 4, blur, -4, 128)
    elif use_clahe:
        img = apply_clahe(img)

    if use_circle_crop:
        img = circle_crop(img)

    img = cv2.resize(img, (image_size, image_size))
    img = np.clip(img, 0, 255).astype(np.uint8)

    # ═══════════════════════════════════════════════════════
    # NaN SAFETY: Check for NaN before saving
    # ═══════════════════════════════════════════════════════
    if np.isnan(img).any() or np.isinf(img).any():
        print(f"⚠️ WARNING: NaN/Inf in preprocessed image from {path}")
        return None

    return img


# ============================================================
# 4. Cache Functions
# ============================================================

def create_preprocessed_cache(config, model_cfg):
    """Preprocess all images and save to cache directory."""
    print("\n" + "=" * 60)
    print(f"CREATING PREPROCESSED IMAGE CACHE ({config.IMAGE_SIZE}x{config.IMAGE_SIZE})")
    print("=" * 60)

    train_df = pd.read_csv(f"{config.SPLITS_DIR}/retinal_train_images.csv")
    val_df = pd.read_csv(f"{config.SPLITS_DIR}/retinal_val_images.csv")
    test_df = pd.read_csv(f"{config.SPLITS_DIR}/retinal_test_images.csv")

    splits = {'train': train_df, 'val': val_df, 'test': test_df}

    for split_name, df in splits.items():
        split_cache_dir = os.path.join(config.CACHE_DIR, split_name)
        os.makedirs(split_cache_dir, exist_ok=True)

        print(f"\nProcessing {split_name} set: {len(df)} images")
        existing_files = set(os.listdir(split_cache_dir))

        cached_count, failed_count, skipped_count = 0, 0, 0

        for idx, row in tqdm(df.iterrows(), total=len(df), desc=f"Caching {split_name}"):
            image_name = row['image']
            cache_filename = f"{image_name}.npy"
            cache_path = os.path.join(split_cache_dir, cache_filename)

            if cache_filename in existing_files:
                skipped_count += 1
                continue

            img_path = os.path.join(config.DATA_DIR, image_name + ".jpeg")
            preprocessed = preprocess_image_for_cache(
                img_path, image_size=config.IMAGE_SIZE,
                use_clahe=model_cfg.USE_CLAHE,
                use_circle_crop=model_cfg.USE_CIRCLE_CROP,
                use_ben_graham=model_cfg.USE_BEN_GRAHAM
            )

            if preprocessed is not None:
                np.save(cache_path, preprocessed)
                cached_count += 1
            else:
                failed_count += 1

        print(f"  Cached: {cached_count}, Skipped: {skipped_count}, Failed: {failed_count}")

    print("\n✓ Cache creation complete!")
    return True


def verify_cache(config):
    """Verify that cache exists and has expected files."""
    splits = ['train', 'val', 'test']
    cache_valid = True

    for split in splits:
        split_dir = os.path.join(config.CACHE_DIR, split)
        if not os.path.exists(split_dir):
            print(f"[WARNING] Cache directory missing: {split_dir}")
            cache_valid = False
            continue

        csv_path = os.path.join(config.SPLITS_DIR, f"retinal_{split}_images.csv")
        df = pd.read_csv(csv_path)

        cached_files = set(os.listdir(split_dir))
        expected_files = set(f"{row['image']}.npy" for _, row in df.iterrows())

        missing = expected_files - cached_files
        if len(missing) > 0:
            print(f"[WARNING] {split}: {len(missing)} files missing from cache")
            cache_valid = False
        else:
            print(f"[OK] {split}: {len(cached_files)} cached files verified")

    return cache_valid


# ============================================================
# 5. Data Augmentation Transforms
# ============================================================

def get_train_transform(image_size=300):
    """Get training augmentation transforms."""
    return transforms.Compose([
        transforms.RandomResizedCrop(image_size, scale=(0.8, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(brightness=0.2, contrast=0.2),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])


def get_val_test_transform(image_size=300):
    """Get validation/test transforms (normalization only)."""
    return transforms.Compose([
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])


# ============================================================
# 6. Dataset Class
# ============================================================

class CachedRetinalDataset(Dataset):
    """Dataset that loads preprocessed images from cache."""

    def __init__(self, df, cache_dir, is_training=True, image_size=300):
        self.df = df.reset_index(drop=True)
        self.cache_dir = cache_dir
        self.is_training = is_training
        self.size = image_size
        self.transform = get_train_transform(image_size) if is_training else get_val_test_transform(image_size)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        image_name = row['image']
        label = float(row['patient_label'])

        cache_path = os.path.join(self.cache_dir, f"{image_name}.npy")

        try:
            img = np.load(cache_path)
            img = img.astype(np.float32) / 255.0
            img = torch.from_numpy(img).permute(2, 0, 1)
        except:
            img = torch.zeros(3, self.size, self.size)

        img = self.transform(img)

        return {
            'image': img,
            'label': torch.tensor(label, dtype=torch.float32)
        }


# ============================================================
# 7. Model Definition
# ============================================================

class BinaryDRClassifier(nn.Module):
    """Binary Diabetic Retinopathy Classifier using EfficientNet backbone."""

    def __init__(self, model_name='efficientnet_b3', pretrained=True, dropout=0.3):
        super().__init__()

        self.model_name = model_name

        if model_name == 'efficientnet_b0':
            weights = models.EfficientNet_B0_Weights.IMAGENET1K_V1 if pretrained else None
            self.backbone = models.efficientnet_b0(weights=weights)
        elif model_name == 'efficientnet_b1':
            weights = models.EfficientNet_B1_Weights.IMAGENET1K_V1 if pretrained else None
            self.backbone = models.efficientnet_b1(weights=weights)
        elif model_name == 'efficientnet_b2':
            weights = models.EfficientNet_B2_Weights.IMAGENET1K_V1 if pretrained else None
            self.backbone = models.efficientnet_b2(weights=weights)
        elif model_name == 'efficientnet_b3':
            weights = models.EfficientNet_B3_Weights.IMAGENET1K_V1 if pretrained else None
            self.backbone = models.efficientnet_b3(weights=weights)
        else:
            raise ValueError(f'Model {model_name} not supported. Use efficientnet_b0, b1, b2, or b3.')

        # Get feature dimension from the backbone
        n = self.backbone.classifier[1].in_features
        self.backbone.classifier = nn.Identity()
        self.feature_dim = n

        # Classifier head (same structure as B2 for fair comparison)
        self.classifier = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(n, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(dropout * 0.5),
            nn.Linear(256, 1)
        )

    def extract_features(self, x):
        """Extract features from backbone for multimodal fusion."""
        return self.backbone(x)

    def forward(self, x):
        """Forward pass returning logits."""
        f = self.backbone(x)
        return self.classifier(f)


# ============================================================
# 8. Freeze/Unfreeze Helper Functions
# ============================================================

def freeze_backbone(model, freeze_bn=False):
    """Freeze all backbone parameters."""
    for param in model.backbone.parameters():
        param.requires_grad = False

    if not freeze_bn:
        for module in model.backbone.modules():
            if isinstance(module, (nn.BatchNorm2d, nn.BatchNorm1d)):
                for param in module.parameters():
                    param.requires_grad = True

    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    total = sum(p.numel() for p in model.parameters())

    print(f"[FREEZE] Backbone frozen. Trainable: {trainable:,} / {total:,} params "
          f"({100*trainable/total:.1f}%)")


def unfreeze_backbone(model):
    """Unfreeze all backbone parameters for full fine-tuning."""
    for param in model.backbone.parameters():
        param.requires_grad = True

    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    total = sum(p.numel() for p in model.parameters())

    print(f"[UNFREEZE] Backbone unfrozen. Trainable: {trainable:,} / {total:,} params "
          f"({100*trainable/total:.1f}%)")


def get_trainable_params(model):
    """Get only trainable parameters for optimizer."""
    return [p for p in model.parameters() if p.requires_grad]


def create_model(cfg):
    """Create and initialize the model."""
    model = BinaryDRClassifier(
        cfg.MODEL_NAME,
        cfg.PRETRAINED,
        cfg.DROPOUT
    )
    model.to(cfg.DEVICE)
    os.makedirs(cfg.SAVE_DIR, exist_ok=True)
    os.makedirs(cfg.FIGURES_DIR, exist_ok=True)

    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    print(f"\n[INFO] Model: {cfg.MODEL_NAME}")
    print(f"[INFO] Device: {cfg.DEVICE}")
    print(f"[INFO] Total parameters: {total_params:,}")
    print(f"[INFO] Trainable parameters: {trainable_params:,}")
    print(f"[INFO] Feature dimension: {model.feature_dim}")

    return model


# ============================================================
# 9. Early Stopping
# ============================================================

class EarlyStopping:
    """Early stopping to prevent overfitting."""

    def __init__(self, patience=7, min_delta=0.001, mode='max'):
        self.patience = patience
        self.min_delta = min_delta
        self.mode = mode
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.best_epoch = 0

    def __call__(self, score, epoch):
        if self.best_score is None:
            self.best_score = score
            self.best_epoch = epoch
            return False

        if self._is_improvement(score):
            self.best_score = score
            self.best_epoch = epoch
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

        return self.early_stop

    def _is_improvement(self, score):
        if self.mode == 'max':
            return score > self.best_score + self.min_delta
        return score < self.best_score - self.min_delta

    def reset(self):
        """Reset early stopping counter (useful when unfreezing)."""
        self.counter = 0


# ════════════════════════════════════════════════════════════
# 10. Training Functions (NaN-SAFE VERSION)
# ════════════════════════════════════════════════════════════

def train_one_epoch(model, loader, criterion, optimizer, device, scaler=None, use_amp=True):
    """Train for one epoch with NaN filtering."""
    model.train()
    total_loss = 0
    preds = []
    labels = []
    skipped_batches = 0  # Track NaN batches
    processed_samples = 0

    for batch_idx, batch in enumerate(tqdm(loader, desc="Train", leave=False)):
        x = batch['image'].to(device)
        y = batch['label'].to(device).unsqueeze(1)

        # ═══════════════════════════════════════════════════
        # NaN CHECK - Skip bad batches
        # ═══════════════════════════════════════════════════
        if torch.isnan(x).any() or torch.isnan(y).any() or torch.isinf(x).any():
            skipped_batches += 1
            continue  # Skip this batch entirely

        optimizer.zero_grad()

        if use_amp and scaler is not None:
            with autocast():
                out = model(x)
                loss = criterion(out, y)

            # Check if loss is NaN (model issue)
            if torch.isnan(loss) or torch.isinf(loss):
                skipped_batches += 1
                continue

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
        else:
            out = model(x)
            loss = criterion(out, y)

            if torch.isnan(loss) or torch.isinf(loss):
                skipped_batches += 1
                continue

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        total_loss += loss.item() * x.size(0)
        processed_samples += x.size(0)

        with torch.no_grad():
            probs = torch.sigmoid(out.float()).cpu().numpy().ravel()
        preds.extend(probs)
        labels.extend(y.cpu().numpy().ravel())

    if skipped_batches > 0:
        print(f"  ⚠️  Skipped {skipped_batches} batches due to NaN/Inf")

    # Prevent division by zero
    if processed_samples == 0 or len(preds) == 0:
        print("  ❌ WARNING: No valid batches processed!")
        return {'loss': 0, 'auc': 0, 'acc': 0}

    epoch_loss = total_loss / processed_samples
    preds = np.array(preds)
    labels = np.array(labels)

    auc = roc_auc_score(labels, preds)
    acc = accuracy_score(labels, (preds > 0.5).astype(int))

    return {'loss': epoch_loss, 'auc': auc, 'acc': acc}


def validate(model, loader, criterion, device, use_amp=True):
    """Validate with NaN filtering."""
    model.eval()
    total_loss = 0
    preds = []
    labels = []
    skipped_batches = 0
    processed_samples = 0

    with torch.no_grad():
        for batch in tqdm(loader, desc="Val", leave=False):
            x = batch['image'].to(device)
            y = batch['label'].to(device).unsqueeze(1)

            # ═══════════════════════════════════════════════════
            # NaN CHECK - Skip bad batches
            # ═══════════════════════════════════════════════════
            if torch.isnan(x).any() or torch.isnan(y).any() or torch.isinf(x).any():
                skipped_batches += 1
                continue

            if use_amp:
                with autocast():
                    out = model(x)
                    loss = criterion(out, y)
            else:
                out = model(x)
                loss = criterion(out, y)

            if torch.isnan(loss) or torch.isinf(loss):
                skipped_batches += 1
                continue

            total_loss += loss.item() * x.size(0)
            processed_samples += x.size(0)

            probs = torch.sigmoid(out.float()).cpu().numpy().ravel()
            preds.extend(probs)
            labels.extend(y.cpu().numpy().ravel())

    if skipped_batches > 0:
        print(f"  ⚠️  Skipped {skipped_batches} batches due to NaN/Inf")

    if processed_samples == 0 or len(preds) == 0:
        print("  ❌ WARNING: No valid batches processed!")
        return {'loss': 0, 'auc': 0, 'acc': 0}

    epoch_loss = total_loss / processed_samples
    preds = np.array(preds)
    labels = np.array(labels)

    auc = roc_auc_score(labels, preds)
    acc = accuracy_score(labels, (preds > 0.5).astype(int))

    return {'loss': epoch_loss, 'auc': auc, 'acc': acc}


# ============================================================
# 11. Two-Stage Training Loop
# ============================================================

def train_model_two_stage(model, train_loader, val_loader, cfg, data_cfg):
    """
    Two-stage training loop:
    - Phase 1: Backbone frozen, train classifier only
    - Phase 2: Full fine-tuning with lower LR
    """

    pos_weight = torch.tensor([cfg.POS_WEIGHT], device=cfg.DEVICE)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

    scaler = GradScaler() if cfg.USE_MIXED_PRECISION and cfg.DEVICE.type == 'cuda' else None
    use_amp = cfg.USE_MIXED_PRECISION and cfg.DEVICE.type == 'cuda'

    early_stopping = EarlyStopping(
        patience=cfg.EARLY_STOPPING_PATIENCE,
        min_delta=cfg.EARLY_STOPPING_MIN_DELTA,
        mode='max'
    )

    best_auc = 0.0
    best_weights = None
    history = {
        'train_loss': [], 'train_auc': [], 'train_acc': [],
        'val_loss': [], 'val_auc': [], 'val_acc': [],
        'lr': [], 'phase': []
    }

    print("\n" + "=" * 70)
    print("TWO-STAGE TRAINING STARTED (NaN-Safe Mode)")
    print("=" * 70)
    print(f"Model: {cfg.MODEL_NAME}")
    print(f"Image Size: {data_cfg.IMAGE_SIZE}x{data_cfg.IMAGE_SIZE}")
    print(f"Phase 1: Epochs 1-{cfg.FREEZE_EPOCHS} (Backbone FROZEN, LR={cfg.LR})")
    print(f"Phase 2: Epochs {cfg.FREEZE_EPOCHS+1}-{cfg.NUM_EPOCHS} (Backbone UNFROZEN, LR={cfg.LR * cfg.UNFREEZE_LR_FACTOR})")
    print(f"Pos weight: {cfg.POS_WEIGHT}")
    print(f"Batch size: {data_cfg.BATCH_SIZE}")
    print(f"Mixed precision: {use_amp}")
    print(f"Early stopping patience: {cfg.EARLY_STOPPING_PATIENCE}")
    print(f"Device: {cfg.DEVICE}")
    print("=" * 70)

    # ─────────────────────────────────────────────────────────
    # PHASE 1: Freeze backbone
    # ─────────────────────────────────────────────────────────
    print("\n" + "─" * 50)
    print("PHASE 1: Training classifier with frozen backbone")
    print("─" * 50)

    freeze_backbone(model, freeze_bn=cfg.FREEZE_BN)

    optimizer = optim.AdamW(
        get_trainable_params(model),
        lr=cfg.LR,
        weight_decay=cfg.WEIGHT_DECAY
    )

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='max', patience=2, factor=0.5, min_lr=1e-6
    )

    start_time = time.time()

    for epoch in range(1, cfg.NUM_EPOCHS + 1):
        epoch_start = time.time()

        # ─────────────────────────────────────────────────────
        # PHASE 2: Unfreeze at FREEZE_EPOCHS + 1
        # ─────────────────────────────────────────────────────
        if epoch == cfg.FREEZE_EPOCHS + 1:
            print("\n" + "─" * 50)
            print("PHASE 2: Fine-tuning entire model (backbone unfrozen)")
            print("─" * 50)

            unfreeze_backbone(model)

            new_lr = cfg.LR * cfg.UNFREEZE_LR_FACTOR
            optimizer = optim.AdamW(
                model.parameters(),
                lr=new_lr,
                weight_decay=cfg.WEIGHT_DECAY
            )

            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode='max', patience=3, factor=0.5, min_lr=1e-6
            )

            early_stopping.reset()
            print(f"[INFO] LR reduced to {new_lr:.2e} for fine-tuning")
            print(f"[INFO] Early stopping counter reset")

        current_lr = optimizer.param_groups[0]['lr']
        phase = 1 if epoch <= cfg.FREEZE_EPOCHS else 2

        print(f"\nEpoch {epoch}/{cfg.NUM_EPOCHS} [Phase {phase}] (LR: {current_lr:.2e})")
        print("-" * 40)

        t = train_one_epoch(model, train_loader, criterion, optimizer,
                           cfg.DEVICE, scaler, use_amp)

        v = validate(model, val_loader, criterion, cfg.DEVICE, use_amp)

        scheduler.step(v['auc'])

        history['train_loss'].append(t['loss'])
        history['train_auc'].append(t['auc'])
        history['train_acc'].append(t['acc'])
        history['val_loss'].append(v['loss'])
        history['val_auc'].append(v['auc'])
        history['val_acc'].append(v['acc'])
        history['lr'].append(current_lr)
        history['phase'].append(phase)

        epoch_time = time.time() - epoch_start

        print(f"Train  Loss: {t['loss']:.4f} | AUC: {t['auc']:.4f} | Acc: {t['acc']:.4f}")
        print(f"Val    Loss: {v['loss']:.4f} | AUC: {v['auc']:.4f} | Acc: {v['acc']:.4f}")
        print(f"Time: {epoch_time:.1f}s")

        if v['auc'] > best_auc:
            best_auc = v['auc']
            best_weights = copy.deepcopy(model.state_dict())

            checkpoint = {
                'epoch': epoch,
                'phase': phase,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_auc': v['auc'],
                'val_acc': v['acc'],
                'feature_dim': model.feature_dim,
                'config': {
                    'model_name': cfg.MODEL_NAME,
                    'image_size': data_cfg.IMAGE_SIZE,
                    'dropout': cfg.DROPOUT,
                    'use_ben_graham': cfg.USE_BEN_GRAHAM,
                    'use_clahe': cfg.USE_CLAHE,
                    'use_circle_crop': cfg.USE_CIRCLE_CROP,
                    'freeze_epochs': cfg.FREEZE_EPOCHS,
                    'unfreeze_lr_factor': cfg.UNFREEZE_LR_FACTOR
                }
            }
            torch.save(checkpoint, os.path.join(cfg.SAVE_DIR, cfg.MODEL_SAVE_NAME))
            print(f"  ✅ Saved best model (Phase {phase}, AUC: {v['auc']:.4f})")

        if phase == 2:
            if early_stopping(v['auc'], epoch):
                print(f"\n⚠️ Early stopping triggered at epoch {epoch}")
                print(f"   Best epoch: {early_stopping.best_epoch} with AUC: {early_stopping.best_score:.4f}")
                break

    total_time = time.time() - start_time

    model.load_state_dict(best_weights)

    print("\n" + "=" * 70)
    print("TWO-STAGE TRAINING COMPLETED")
    print("=" * 70)
    print(f"Total time: {total_time:.1f}s ({total_time/60:.2f} min)")
    print(f"Epochs trained: {len(history['train_loss'])}")
    print(f"  Phase 1 (frozen): {min(cfg.FREEZE_EPOCHS, len(history['train_loss']))} epochs")
    print(f"  Phase 2 (fine-tuned): {max(0, len(history['train_loss']) - cfg.FREEZE_EPOCHS)} epochs")
    print(f"Best Validation AUC: {best_auc:.4f}")

    return model, history


# ============================================================
# 12. Threshold Tuning
# ============================================================

def tune_threshold(labels, probs):
    """Find optimal threshold for F1 score."""
    labels = np.array(labels)
    probs = np.array(probs)

    best_thr = 0.5
    best_f1 = 0.0

    print("\n" + "-" * 70)
    print(f"{'Threshold':<12} {'Precision':<12} {'Recall':<12} {'F1-Score':<12}")
    print("-" * 70)

    for thr in np.linspace(0.1, 0.9, 17):
        preds_bin = (probs >= thr).astype(int)
        p = precision_score(labels, preds_bin, zero_division=0)
        r = recall_score(labels, preds_bin, zero_division=0)
        f1 = f1_score(labels, preds_bin, zero_division=0)

        print(f"{thr:<12.2f} {p:<12.3f} {r:<12.3f} {f1:<12.3f}")

        if f1 > best_f1:
            best_f1 = f1
            best_thr = thr

    print("-" * 70)
    print(f"\n✓ Best F1 threshold: {best_thr:.2f} (F1 = {best_f1:.3f})")

    return best_thr, best_f1


# ============================================================
# 13. Evaluation
# ============================================================

def evaluate_model(model, loader, device, model_cfg, data_cfg, use_amp=True):
    """Comprehensive model evaluation with threshold tuning."""
    model.eval()
    probs = []
    labels = []

    with torch.no_grad():
        for batch in tqdm(loader, desc="Test"):
            x = batch['image'].to(device)
            y = batch['label'].to(device)

            if use_amp:
                with autocast():
                    out = model(x)
            else:
                out = model(x)

            p = torch.sigmoid(out.float()).cpu().numpy().ravel()
            probs.extend(p)
            labels.extend(y.cpu().numpy().ravel())

    probs = np.array(probs)
    labels = np.array(labels)

    binary_default = (probs >= 0.5).astype(int)

    print("\n" + "=" * 60)
    print("EVALUATION RESULTS")
    print("=" * 60)

    print("\n--- Results with Default Threshold (0.50) ---")
    print("\nClassification Report:")
    print(classification_report(labels, binary_default, target_names=['No DR', 'DR']))

    print("\n--- Threshold Optimization ---")
    best_thr, best_f1 = tune_threshold(labels, probs)

    binary_best = (probs >= best_thr).astype(int)

    print(f"\n--- Results with Optimal Threshold ({best_thr:.2f}) ---")
    print("\nClassification Report:")
    print(classification_report(labels, binary_best, target_names=['No DR', 'DR']))

    auc = roc_auc_score(labels, probs)

    acc_default = accuracy_score(labels, binary_default)
    prec_default = precision_score(labels, binary_default, zero_division=0)
    rec_default = recall_score(labels, binary_default, zero_division=0)
    f1_default = f1_score(labels, binary_default, zero_division=0)

    acc_optimal = accuracy_score(labels, binary_best)
    prec_optimal = precision_score(labels, binary_best, zero_division=0)
    rec_optimal = recall_score(labels, binary_best, zero_division=0)
    f1_optimal = f1_score(labels, binary_best, zero_division=0)

    print("\n" + "=" * 60)
    print("THRESHOLD COMPARISON")
    print("=" * 60)

    print(f"""
┌─────────────────┬──────────────────┬──────────────────┬─────────────┐
│ Metric          │ Threshold = 0.50 │ Threshold = {best_thr:.2f} │ Change      │
├─────────────────┼──────────────────┼──────────────────┼─────────────┤
│ Accuracy        │ {acc_default:.4f}           │ {acc_optimal:.4f}           │ {acc_optimal - acc_default:+.4f}      │
│ Precision       │ {prec_default:.4f}           │ {prec_optimal:.4f}           │ {prec_optimal - prec_default:+.4f}      │
│ Recall          │ {rec_default:.4f}           │ {rec_optimal:.4f}           │ {rec_optimal - rec_default:+.4f}      │
│ F1-Score        │ {f1_default:.4f}           │ {f1_optimal:.4f}           │ {f1_optimal - f1_default:+.4f}      │
└─────────────────┴──────────────────┴──────────────────┴─────────────┘

AUC-ROC: {auc:.4f} (threshold-independent)
""")

    # Visualizations
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    fig.suptitle(f'Test Set Evaluation ({model_cfg.MODEL_NAME} @ {data_cfg.IMAGE_SIZE})',
                 fontsize=14, fontweight='bold')

    cm_default = confusion_matrix(labels, binary_default)
    sns.heatmap(cm_default, annot=True, fmt='d', cmap='Blues', ax=axes[0],
                xticklabels=['No DR', 'DR'], yticklabels=['No DR', 'DR'])
    axes[0].set_title('Confusion Matrix (thr=0.50)')
    axes[0].set_xlabel('Predicted')
    axes[0].set_ylabel('Actual')

    cm_optimal = confusion_matrix(labels, binary_best)
    sns.heatmap(cm_optimal, annot=True, fmt='d', cmap='Greens', ax=axes[1],
                xticklabels=['No DR', 'DR'], yticklabels=['No DR', 'DR'])
    axes[1].set_title(f'Confusion Matrix (thr={best_thr:.2f})')
    axes[1].set_xlabel('Predicted')
    axes[1].set_ylabel('Actual')

    fpr, tpr, _ = roc_curve(labels, probs)
    axes[2].plot(fpr, tpr, 'b-', linewidth=2, label=f'ROC (AUC={auc:.3f})')
    axes[2].plot([0, 1], [0, 1], 'k--')
    axes[2].set_xlabel('False Positive Rate')
    axes[2].set_ylabel('True Positive Rate')
    axes[2].set_title('ROC Curve')
    axes[2].legend()
    axes[2].grid(alpha=0.3)

    plt.tight_layout()
    eval_fig_path = os.path.join(model_cfg.FIGURES_DIR, f"evaluation_{model_cfg.MODEL_NAME}.png")
    plt.savefig(eval_fig_path, dpi=150, bbox_inches='tight')
    plt.show()
    print(f"Saved: {eval_fig_path}")

    print(f"\nTest AUC: {auc:.4f}")

    return {
        'auc': auc,
        'optimal_threshold': best_thr,
        'accuracy_default': acc_default,
        'accuracy_optimal': acc_optimal,
        'precision_default': prec_default,
        'precision_optimal': prec_optimal,
        'recall_default': rec_default,
        'recall_optimal': rec_optimal,
        'f1_default': f1_default,
        'f1_optimal': f1_optimal
    }


# ============================================================
# 14. Plotting Functions
# ============================================================

def plot_training_history_two_stage(history, freeze_epochs, model_cfg, data_cfg, save_path=None):
    """Plot training curves with phase markers."""
    epochs = range(1, len(history['train_loss']) + 1)

    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    fig.suptitle(f'Two-Stage Training History ({model_cfg.MODEL_NAME} @ {data_cfg.IMAGE_SIZE})',
                 fontsize=14, fontweight='bold')

    # Loss
    axes[0, 0].plot(epochs, history['train_loss'], 'b-', label='Train')
    axes[0, 0].plot(epochs, history['val_loss'], 'r-', label='Validation')
    if freeze_epochs < len(epochs):
        axes[0, 0].axvline(x=freeze_epochs + 0.5, color='green', linestyle='--',
                          label='Unfreeze', alpha=0.7)
    axes[0, 0].set_xlabel('Epoch')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].set_title('Training vs Validation Loss')
    axes[0, 0].legend()
    axes[0, 0].grid(alpha=0.3)

    # AUC
    axes[0, 1].plot(epochs, history['train_auc'], 'b-', label='Train')
    axes[0, 1].plot(epochs, history['val_auc'], 'r-', label='Validation')
    if freeze_epochs < len(epochs):
        axes[0, 1].axvline(x=freeze_epochs + 0.5, color='green', linestyle='--',
                          label='Unfreeze', alpha=0.7)
    axes[0, 1].set_xlabel('Epoch')
    axes[0, 1].set_ylabel('AUC-ROC')
    axes[0, 1].set_title('Training vs Validation AUC')
    axes[0, 1].legend()
    axes[0, 1].grid(alpha=0.3)

    # Accuracy
    axes[1, 0].plot(epochs, history['train_acc'], 'b-', label='Train')
    axes[1, 0].plot(epochs, history['val_acc'], 'r-', label='Validation')
    if freeze_epochs < len(epochs):
        axes[1, 0].axvline(x=freeze_epochs + 0.5, color='green', linestyle='--',
                          label='Unfreeze', alpha=0.7)
    axes[1, 0].set_xlabel('Epoch')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].set_title('Training vs Validation Accuracy')
    axes[1, 0].legend()
    axes[1, 0].grid(alpha=0.3)

    # Learning Rate
    axes[1, 1].plot(epochs, history['lr'], 'g-')
    if freeze_epochs < len(epochs):
        axes[1, 1].axvline(x=freeze_epochs + 0.5, color='green', linestyle='--',
                          label='Unfreeze', alpha=0.7)
    axes[1, 1].set_xlabel('Epoch')
    axes[1, 1].set_ylabel('Learning Rate')
    axes[1, 1].set_title('Learning Rate Schedule')
    axes[1, 1].set_yscale('log')
    axes[1, 1].legend()
    axes[1, 1].grid(alpha=0.3)

    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=150, bbox_inches='tight')
        print(f"Saved: {save_path}")

    plt.show()


# ============================================================
# 15. Model Comparison Table
# ============================================================

def print_model_comparison(test_results, model_cfg, data_cfg):
    """Print comparison with previous models."""

    print("\n" + "=" * 70)
    print("MODEL COMPARISON (ALL EXPERIMENTS)")
    print("=" * 70)

    print(f"""
┌──────────────────┬────────┬───────────┬───────┬────────┬─────────────┐
│ Model            │ Params │ Image Size│ AUC   │ F1     │ Feature Dim │
├──────────────────┼────────┼───────────┼───────┼────────┼─────────────┤
│ EfficientNet-B0  │  4.3M  │ 224×224   │ 0.764 │ 0.580  │ 1280        │
│ EfficientNet-B2  │  8.1M  │ 256×256   │ 0.772 │ 0.598  │ 1408        │
│ EfficientNet-B3  │ 12.0M  │ 300×300   │ {test_results['auc']:.3f} │ {test_results['f1_optimal']:.3f}  │ 1536        │
└──────────────────┴────────┴───────────┴───────┴────────┴─────────────┘

B0 → B2 improvement: +0.008 AUC
B2 → B3 improvement: {test_results['auc'] - 0.7715:+.3f} AUC
""")


# ============================================================
# 16. Main Execution
# ============================================================

if __name__ == "__main__":

    # Initialize
    config = Config()
    model_cfg = ModelConfig()
    seed_everything(config.SEED)

    # Create all directories
    os.makedirs(config.CACHE_DIR, exist_ok=True)
    os.makedirs(model_cfg.SAVE_DIR, exist_ok=True)
    os.makedirs(model_cfg.FIGURES_DIR, exist_ok=True)

    # Print configuration
    print("\n" + "=" * 60)
    print("EXPERIMENT CONFIGURATION")
    print("=" * 60)
    print(f"Model:       {model_cfg.MODEL_NAME}")
    print(f"Image Size:  {config.IMAGE_SIZE}x{config.IMAGE_SIZE}")
    print(f"Batch Size:  {config.BATCH_SIZE}")
    print(f"Cache Dir:   {config.CACHE_DIR}")
    print(f"Save Dir:    {model_cfg.SAVE_DIR}")
    print(f"Figures Dir: {model_cfg.FIGURES_DIR}")
    print("=" * 60)

    # ─────────────────────────────────────────────────────────
    # Step 1: Check/Create Cache (new cache for 300 resolution)
    # ─────────────────────────────────────────────────────────
    if model_cfg.USE_CACHED_IMAGES:
        print("\n" + "-" * 40)
        print(f"Checking preprocessed image cache ({config.IMAGE_SIZE}x{config.IMAGE_SIZE})...")
        print("-" * 40)

        cache_exists = os.path.exists(config.CACHE_DIR)

        if not cache_exists or not verify_cache(config):
            print(f"\n[INFO] Cache for {config.IMAGE_SIZE}x{config.IMAGE_SIZE} missing. Creating cache...")
            create_preprocessed_cache(config, model_cfg)
            print("\n[INFO] Verifying cache...")
            verify_cache(config)
        else:
            print("\n[INFO] Cache verified successfully!")

    # ─────────────────────────────────────────────────────────
    # Step 2: Load CSV splits
    # ─────────────────────────────────────────────────────────
    print("\n" + "-" * 40)
    print("Loading data splits...")
    print("-" * 40)

    train_df = pd.read_csv(f"{config.SPLITS_DIR}/retinal_train_images.csv")
    val_df = pd.read_csv(f"{config.SPLITS_DIR}/retinal_val_images.csv")
    test_df = pd.read_csv(f"{config.SPLITS_DIR}/retinal_test_images.csv")

    print(f"Train: {len(train_df)} images")
    print(f"Val:   {len(val_df)} images")
    print(f"Test:  {len(test_df)} images")

    print(f"\nTrain class distribution:")
    print(train_df['patient_label'].value_counts().to_dict())

    # ─────────────────────────────────────────────────────────
    # Step 3: Create DataLoaders
    # ─────────────────────────────────────────────────────────
    print("\n" + "-" * 40)
    print("Creating DataLoaders...")
    print("-" * 40)

    train_dataset = CachedRetinalDataset(
        train_df,
        cache_dir=os.path.join(config.CACHE_DIR, 'train'),
        is_training=True,
        image_size=config.IMAGE_SIZE
    )

    val_dataset = CachedRetinalDataset(
        val_df,
        cache_dir=os.path.join(config.CACHE_DIR, 'val'),
        is_training=False,
        image_size=config.IMAGE_SIZE
    )

    test_dataset = CachedRetinalDataset(
        test_df,
        cache_dir=os.path.join(config.CACHE_DIR, 'test'),
        is_training=False,
        image_size=config.IMAGE_SIZE
    )

    train_loader = DataLoader(
        train_dataset, batch_size=config.BATCH_SIZE, shuffle=True,
        num_workers=config.NUM_WORKERS, drop_last=True, pin_memory=True
    )

    val_loader = DataLoader(
        val_dataset, batch_size=config.BATCH_SIZE, shuffle=False,
        num_workers=config.NUM_WORKERS, pin_memory=True
    )

    test_loader = DataLoader(
        test_dataset, batch_size=config.BATCH_SIZE, shuffle=False,
        num_workers=config.NUM_WORKERS, pin_memory=True
    )

    print(f"Train batches: {len(train_loader)}")
    print(f"Val batches:   {len(val_loader)}")
    print(f"Test batches:  {len(test_loader)}")

    # ═══════════════════════════════════════════════════════
    # QUICK NaN CHECK (Optional - Remove after first run)
    # ═══════════════════════════════════════════════════════
    print("\n" + "="*70)
    print("🔍 QUICK NaN CHECK")
    print("="*70)

    nan_count = 0
    for i, batch in enumerate(train_loader):
        if i >= 10:
            break
        if torch.isnan(batch['image']).any() or torch.isnan(batch['label']).any():
            nan_count += 1

    print(f"NaN batches in first 10: {nan_count}/10")

    if nan_count > 0:
        print("⚠️  NaN detected - NaN-safe training mode is ACTIVE")
        print("   (Bad batches will be automatically skipped)")
    else:
        print("✅ Sample looks clean!")

    print("="*70 + "\n")

    # ─────────────────────────────────────────────────────────
    # Step 4: Create and train model (TWO-STAGE)
    # ─────────────────────────────────────────────────────────
    model = create_model(model_cfg)

    trained_model, history = train_model_two_stage(model, train_loader, val_loader, model_cfg, config)

    # ─────────────────────────────────────────────────────────
    # Step 5: Evaluate on test set
    # ─────────────────────────────────────────────────────────
    use_amp = model_cfg.USE_MIXED_PRECISION and model_cfg.DEVICE.type == 'cuda'
    test_results = evaluate_model(trained_model, test_loader, model_cfg.DEVICE, model_cfg, config, use_amp)

    # ─────────────────────────────────────────────────────────
    # Step 6: Plot training history
    # ─────────────────────────────────────────────────────────
    plot_training_history_two_stage(
        history,
        freeze_epochs=model_cfg.FREEZE_EPOCHS,
        model_cfg=model_cfg,
        data_cfg=config,
        save_path=os.path.join(model_cfg.FIGURES_DIR, f"training_history_{model_cfg.MODEL_NAME}.png")
    )

    # ─────────────────────────────────────────────────────────
    # Step 7: Save final results
    # ─────────────────────────────────────────────────────────
    checkpoint_path = os.path.join(model_cfg.SAVE_DIR, model_cfg.MODEL_SAVE_NAME)
    checkpoint = torch.load(checkpoint_path, weights_only=False)
    checkpoint['test_results'] = test_results
    checkpoint['optimal_threshold'] = test_results['optimal_threshold']
    checkpoint['training_history'] = history
    torch.save(checkpoint, checkpoint_path)

    print(f"\n✅ Two-stage training & evaluation complete!")
    print(f"   Model saved at: {checkpoint_path}")

    # ─────────────────────────────────────────────────────────
    # Step 8: Print model comparison
    # ─────────────────────────────────────────────────────────
    print_model_comparison(test_results, model_cfg, config)

    # ─────────────────────────────────────────────────────────
    # Summary
    # ─────────────────────────────────────────────────────────
    print("\n" + "=" * 70)
    print("TWO-STAGE TRAINING SUMMARY")
    print("=" * 70)

    phase1_epochs = min(model_cfg.FREEZE_EPOCHS, len(history['train_loss']))
    phase2_epochs = max(0, len(history['train_loss']) - model_cfg.FREEZE_EPOCHS)

    print(f"""
Model: {model_cfg.MODEL_NAME}
Image Size: {config.IMAGE_SIZE}x{config.IMAGE_SIZE}
─────────────────────────────────────────────────

Data:
  Train images: {len(train_df)}
  Val images:   {len(val_df)}
  Test images:  {len(test_df)}

Two-Stage Training:
  Phase 1 (Frozen backbone):
    Epochs:         {phase1_epochs}
    Learning rate:  {model_cfg.LR}
    BatchNorm:      {'Frozen' if model_cfg.FREEZE_BN else 'Trainable'}

  Phase 2 (Full fine-tuning):
    Epochs:         {phase2_epochs}
    Learning rate:  {model_cfg.LR * model_cfg.UNFREEZE_LR_FACTOR}

  Total epochs:     {len(history['train_loss'])}
  Batch size:       {config.BATCH_SIZE}
  Pos weight:       {model_cfg.POS_WEIGHT}
  Mixed precision:  {model_cfg.USE_MIXED_PRECISION}

Test Results (Threshold = 0.50):
  AUC:          {test_results['auc']:.4f}
  Accuracy:     {test_results['accuracy_default']:.4f}
  Precision:    {test_results['precision_default']:.4f}
  Recall:       {test_results['recall_default']:.4f}
  F1:           {test_results['f1_default']:.4f}

Test Results (Threshold = {test_results['optimal_threshold']:.2f}):
  Accuracy:     {test_results['accuracy_optimal']:.4f}
  Precision:    {test_results['precision_optimal']:.4f}
  Recall:       {test_results['recall_optimal']:.4f}
  F1:           {test_results['f1_optimal']:.4f}

Output Files:
  Model:    {model_cfg.SAVE_DIR}/{model_cfg.MODEL_SAVE_NAME}
  Figures:  {model_cfg.FIGURES_DIR}/

─────────────────────────────────────────────────
""")

    # ─────────────────────────────────────────────────────────
    # Helper code for loading
    # ─────────────────────────────────────────────────────────
    print("\n" + "=" * 70)
    print("HELPER CODE FOR LOADING MODEL")
    print("=" * 70)

    helper_code = f'''
# Load trained EfficientNet-B3 model for multimodal fusion:

import torch
import torch.nn as nn
from torchvision import models

class BinaryDRClassifier(nn.Module):
    def __init__(self, model_name='efficientnet_b3', pretrained=False, dropout=0.3):
        super().__init__()
        self.backbone = models.efficientnet_b3(weights=None)
        n = self.backbone.classifier[1].in_features
        self.backbone.classifier = nn.Identity()
        self.feature_dim = n  # 1536 for B3
        self.classifier = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(n, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(dropout * 0.5),
            nn.Linear(256, 1)
        )

    def extract_features(self, x):
        return self.backbone(x)

    def forward(self, x):
        f = self.backbone(x)
        return self.classifier(f)

def load_retinal_model(checkpoint_path, device='cpu'):
    checkpoint = torch.load(checkpoint_path, map_location=device)
    config = checkpoint.get('config', {{}})

    model = BinaryDRClassifier(
        model_name=config.get('model_name', 'efficientnet_b3'),
        pretrained=False,
        dropout=config.get('dropout', 0.3)
    )
    model.load_state_dict(checkpoint['model_state_dict'])
    model.to(device)
    model.eval()

    return model, checkpoint

# Usage:
# model, checkpoint = load_retinal_model('{model_cfg.MODEL_SAVE_NAME}')
# optimal_threshold = checkpoint['optimal_threshold']
# features = model.extract_features(images)  # Shape: (B, 1536)
'''

    print(helper_code)

    print("\n" + "=" * 70)
    print("✓ PIPELINE COMPLETE")
    print("=" * 70)
# Out:
# ======================================================================
# RETINAL CNN TRAINING PIPELINE (EfficientNet-B3 @ 300)
# ======================================================================
# [INFO] Random seed set to 42
#
# ============================================================
# EXPERIMENT CONFIGURATION
# ============================================================
# Model:       efficientnet_b3
# Image Size:  300x300
# Batch Size:  8
# Cache Dir:   /content/drive/MyDrive/MULTIMODAL/datasets/EYEPACS/preprocessed_cache_300
# Save Dir:    /content/drive/MyDrive/MULTIMODAL/models/efficientnet_b3_experiment
# Figures Dir: /content/drive/MyDrive/MULTIMODAL/models/efficientnet_b3_experiment/figures
# ============================================================
#
# ----------------------------------------
# Checking preprocessed image cache (300x300)...
# ----------------------------------------
# [OK] train: 15128 cached files verified
# [OK] val: 5267 cached files verified
# [OK] test: 5266 cached files verified
#
# [INFO] Cache verified successfully!
#
# ----------------------------------------
# Loading data splits...
# ----------------------------------------
# Train: 15128 images
# Val:   5267 images
# Test:  5266 images
#
# Train class distribution:
# {0: 7566, 1: 7562}
#
# ----------------------------------------
# Creating DataLoaders...
# ----------------------------------------
# Train batches: 1891
# Val batches:   659
# Test batches:  659
#
# ======================================================================
# 🔍 QUICK NaN CHECK
# ======================================================================
# NaN batches in first 10: 0/10
# ✅ Sample looks clean!
# ======================================================================
#
# Downloading: "https://download.pytorch.org/models/efficientnet_b3_rwightman-b3899882.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b3_rwightman-b3899882.pth
# 100%|██████████| 47.2M/47.2M [00:00<00:00, 233MB/s]
# [INFO] Model: efficientnet_b3
# [INFO] Device: cuda
# [INFO] Total parameters: 11,090,473
# [INFO] Trainable parameters: 11,090,473
# [INFO] Feature dimension: 1536
#
# ======================================================================
# TWO-STAGE TRAINING STARTED (NaN-Safe Mode)
# ======================================================================
# Model: efficientnet_b3
# Image Size: 300x300
# Phase 1: Epochs 1-5 (Backbone FROZEN, LR=0.0001)
# Phase 2: Epochs 6-40 (Backbone UNFROZEN, LR=5e-05)
# Pos weight: 2.0
# Batch size: 8
# Mixed precision: True
# Early stopping patience: 7
# Device: cuda
# ======================================================================
#
# ──────────────────────────────────────────────────
# PHASE 1: Training classifier with frozen backbone
# ──────────────────────────────────────────────────
# [FREEZE] Backbone frozen. Trainable: 481,537 / 11,090,473 params (4.3%)
#
# Epoch 1/40 [Phase 1] (LR: 1.00e-04)
# ----------------------------------------
#   ⚠️  Skipped 4 batches due to NaN/Inf
# Train  Loss: 0.9700 | AUC: 0.6352 | Acc: 0.5869
# Val    Loss: 1.0541 | AUC: 0.6346 | Acc: 0.5385
# Time: 3116.3s
#   ✅ Saved best model (Phase 1, AUC: 0.6346)
#
# Epoch 2/40 [Phase 1] (LR: 1.00e-04)
# ----------------------------------------
#   ⚠️  Skipped 3 batches due to NaN/Inf
# Train  Loss: 0.9186 | AUC: 0.6573 | Acc: 0.5777
# Val    Loss: 1.1506 | AUC: 0.6582 | Acc: 0.5298
# Time: 145.4s
#   ✅ Saved best model (Phase 1, AUC: 0.6582)
#
# Epoch 3/40 [Phase 1] (LR: 1.00e-04)
# ----------------------------------------
#   ⚠️  Skipped 3 batches due to NaN/Inf
# Train  Loss: 0.8984 | AUC: 0.6748 | Acc: 0.5842
# Val    Loss: 0.9596 | AUC: 0.6760 | Acc: 0.5751
# Time: 147.1s
#   ✅ Saved best model (Phase 1, AUC: 0.6760)
#
# Epoch 4/40 [Phase 1] (LR: 1.00e-04)
# ----------------------------------------
#   ⚠️  Skipped 3 batches due to NaN/Inf
# Train  Loss: 0.8863 | AUC: 0.6862 | Acc: 0.5916
# Val    Loss: 1.0285 | AUC: 0.6716 | Acc: 0.4999
# Time: 145.2s
#
# Epoch 5/40 [Phase 1] (LR: 1.00e-04)
# ----------------------------------------
#   ⚠️  Skipped 3 batches due to NaN/Inf
# Train  Loss: 0.8790 | AUC: 0.6938 | Acc: 0.5958
# Val    Loss: 0.9816 | AUC: 0.6729 | Acc: 0.5211
# Time: 148.2s
#
# ──────────────────────────────────────────────────
# PHASE 2: Fine-tuning entire model (backbone unfrozen)
# ──────────────────────────────────────────────────
# [UNFREEZE] Backbone unfrozen. Trainable: 11,090,473 / 11,090,473 params (100.0%)
# [INFO] LR reduced to 5.00e-05 for fine-tuning
# [INFO] Early stopping counter reset
#
# Epoch 6/40 [Phase 2] (LR: 5.00e-05)
# ----------------------------------------
#   ⚠️  Skipped 1 batches due to NaN/Inf
# Train  Loss: 0.8500 | AUC: 0.7245 | Acc: 0.6265
# Val    Loss: 0.8329 | AUC: 0.7427 | Acc: 0.6480
# Time: 184.8s
#   ✅ Saved best model (Phase 2, AUC: 0.7427)
#
# Epoch 7/40 [Phase 2] (LR: 5.00e-05)
# ----------------------------------------
# Train  Loss: 0.8121 | AUC: 0.7635 | Acc: 0.6697
# Val    Loss: 0.7812 | AUC: 0.7612 | Acc: 0.6774
# Time: 184.4s
#   ✅ Saved best model (Phase 2, AUC: 0.7612)
#
# Epoch 8/40 [Phase 2] (LR: 5.00e-05)
# ----------------------------------------
# Train  Loss: 0.7886 | AUC: 0.7803 | Acc: 0.6829
# Val    Loss: 0.8021 | AUC: 0.7752 | Acc: 0.6357
# Time: 184.0s
#   ✅ Saved best model (Phase 2, AUC: 0.7752)
#
# Epoch 9/40 [Phase 2] (LR: 5.00e-05)
# ----------------------------------------
# Train  Loss: 0.7529 | AUC: 0.8053 | Acc: 0.7097
# Val    Loss: 0.7515 | AUC: 0.7844 | Acc: 0.7367
# Time: 184.4s
#   ✅ Saved best model (Phase 2, AUC: 0.7844)
#
# Epoch 10/40 [Phase 2] (LR: 5.00e-05)
# ----------------------------------------
# Train  Loss: 0.7267 | AUC: 0.8217 | Acc: 0.7235
# Val    Loss: 0.8082 | AUC: 0.7874 | Acc: 0.6649
# Time: 184.5s
#   ✅ Saved best model (Phase 2, AUC: 0.7874)
#
# Epoch 11/40 [Phase 2] (LR: 5.00e-05)
# ----------------------------------------
# Train  Loss: 0.7089 | AUC: 0.8344 | Acc: 0.7389
# Val    Loss: 0.8000 | AUC: 0.7946 | Acc: 0.6742
# Time: 185.3s
#   ✅ Saved best model (Phase 2, AUC: 0.7946)
#
# Epoch 12/40 [Phase 2] (LR: 5.00e-05)
# ----------------------------------------
# Train  Loss: 0.6823 | AUC: 0.8479 | Acc: 0.7524
# Val    Loss: 0.7688 | AUC: 0.7887 | Acc: 0.6670
# Time: 185.3s
#
# Epoch 13/40 [Phase 2] (LR: 5.00e-05)
# ----------------------------------------
# Train  Loss: 0.6553 | AUC: 0.8640 | Acc: 0.7679
# Val    Loss: 0.8083 | AUC: 0.7916 | Acc: 0.6835
# Time: 182.1s
#
# Epoch 14/40 [Phase 2] (LR: 5.00e-05)
# ----------------------------------------
# Train  Loss: 0.6395 | AUC: 0.8720 | Acc: 0.7778
# Val    Loss: 0.8430 | AUC: 0.7870 | Acc: 0.6850
# Time: 183.0s
#
# Epoch 15/40 [Phase 2] (LR: 5.00e-05)
# ----------------------------------------
# Train  Loss: 0.6127 | AUC: 0.8850 | Acc: 0.7891
# Val    Loss: 0.8781 | AUC: 0.7894 | Acc: 0.6822
# Time: 183.3s
#
# Epoch 16/40 [Phase 2] (LR: 2.50e-05)
# ----------------------------------------
# Train  Loss: 0.5693 | AUC: 0.9018 | Acc: 0.8125
# Val    Loss: 0.9313 | AUC: 0.7849 | Acc: 0.7224
# Time: 181.0s
#
# Epoch 17/40 [Phase 2] (LR: 2.50e-05)
# ----------------------------------------
# Train  Loss: 0.5437 | AUC: 0.9142 | Acc: 0.8269
# Val    Loss: 0.9265 | AUC: 0.7825 | Acc: 0.7198
# Time: 182.6s
#
# Epoch 18/40 [Phase 2] (LR: 2.50e-05)
# ----------------------------------------
# Train  Loss: 0.5196 | AUC: 0.9225 | Acc: 0.8397
# Val    Loss: 0.9801 | AUC: 0.7818 | Acc: 0.7217
# Time: 181.8s
#
# ⚠️ Early stopping triggered at epoch 18
#    Best epoch: 11 with AUC: 0.7946
#
# ======================================================================
# TWO-STAGE TRAINING COMPLETED
# ======================================================================
# Total time: 6099.5s (101.66 min)
# Epochs trained: 18
#   Phase 1 (frozen): 5 epochs
#   Phase 2 (fine-tuned): 13 epochs
# Best Validation AUC: 0.7946
# Test: 100%|██████████| 659/659 [38:01<00:00,  3.46s/it]
# ============================================================
# EVALUATION RESULTS
# ============================================================
#
# --- Results with Default Threshold (0.50) ---
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        No DR       0.87      0.63      0.73      3647
#           DR       0.48      0.78      0.60      1619
#
#     accuracy                           0.67      5266
#    macro avg       0.67      0.70      0.66      5266
# weighted avg       0.75      0.67      0.69      5266
#
#
# --- Threshold Optimization ---
#
# ----------------------------------------------------------------------
# Threshold    Precision    Recall       F1-Score
# ----------------------------------------------------------------------
# 0.10         0.321        0.977        0.483
# 0.15         0.333        0.960        0.494
# 0.20         0.350        0.938        0.509
# 0.25         0.368        0.919        0.526
# 0.30         0.385        0.901        0.540
# 0.35         0.407        0.875        0.555
# 0.40         0.428        0.842        0.568
# 0.45         0.452        0.812        0.580
# 0.50         0.482        0.784        0.597
# 0.55         0.502        0.745        0.600
# 0.60         0.536        0.714        0.612
# 0.65         0.567        0.681        0.619
# 0.70         0.605        0.649        0.626
# 0.75         0.643        0.609        0.626
# 0.80         0.703        0.568        0.628
# 0.85         0.769        0.523        0.622
# 0.90         0.831        0.455        0.588
# ----------------------------------------------------------------------
#
# ✓ Best F1 threshold: 0.80 (F1 = 0.628)
#
# --- Results with Optimal Threshold (0.80) ---
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        No DR       0.82      0.89      0.86      3647
#           DR       0.70      0.57      0.63      1619
#
#     accuracy                           0.79      5266
#    macro avg       0.76      0.73      0.74      5266
# weighted avg       0.79      0.79      0.79      5266
#
#
# ============================================================
# THRESHOLD COMPARISON
# ============================================================
#
# ┌─────────────────┬──────────────────┬──────────────────┬─────────────┐
# │ Metric          │ Threshold = 0.50 │ Threshold = 0.80 │ Change      │
# ├─────────────────┼──────────────────┼──────────────────┼─────────────┤
# │ Accuracy        │ 0.6741           │ 0.7934           │ +0.1193      │
# │ Precision       │ 0.4816           │ 0.7031           │ +0.2215      │
# │ Recall          │ 0.7844           │ 0.5676           │ -0.2168      │
# │ F1-Score        │ 0.5968           │ 0.6282           │ +0.0314      │
# └─────────────────┴──────────────────┴──────────────────┴─────────────┘
#
# AUC-ROC: 0.7965 (threshold-independent)
# Saved: /content/drive/MyDrive/MULTIMODAL/models/efficientnet_b3_experiment/figures/evaluation_efficientnet_b3.png
#
# Test AUC: 0.7965
# Saved: /content/drive/MyDrive/MULTIMODAL/models/efficientnet_b3_experiment/figures/training_history_efficientnet_b3.png
# ✅ Two-stage training & evaluation complete!
#    Model saved at: /content/drive/MyDrive/MULTIMODAL/models/efficientnet_b3_experiment/efficientnet_b3_binary_dr_twostage.pth
#
# ======================================================================
# MODEL COMPARISON (ALL EXPERIMENTS)
# ======================================================================
#
# ┌──────────────────┬────────┬───────────┬───────┬────────┬─────────────┐
# │ Model            │ Params │ Image Size│ AUC   │ F1     │ Feature Dim │
# ├──────────────────┼────────┼───────────┼───────┼────────┼─────────────┤
# │ EfficientNet-B0  │  4.3M  │ 224×224   │ 0.764 │ 0.580  │ 1280        │
# │ EfficientNet-B2  │  8.1M  │ 256×256   │ 0.772 │ 0.598  │ 1408        │
# │ EfficientNet-B3  │ 12.0M  │ 300×300   │ 0.797 │ 0.628  │ 1536        │
# └──────────────────┴────────┴───────────┴───────┴────────┴─────────────┘
#
# B0 → B2 improvement: +0.008 AUC
# B2 → B3 improvement: +0.025 AUC
#
#
# ======================================================================
# TWO-STAGE TRAINING SUMMARY
# ======================================================================
#
# Model: efficientnet_b3
# Image Size: 300x300
# ─────────────────────────────────────────────────
#
# Data:
#   Train images: 15128
#   Val images:   5267
#   Test images:  5266
#
# Two-Stage Training:
#   Phase 1 (Frozen backbone):
#     Epochs:         5
#     Learning rate:  0.0001
#     BatchNorm:      Trainable
#
#   Phase 2 (Full fine-tuning):
#     Epochs:         13
#     Learning rate:  5e-05
#
#   Total epochs:     18
#   Batch size:       8
#   Pos weight:       2.0
#   Mixed precision:  True
#
# Test Results (Threshold = 0.50):
#   AUC:          0.7965
#   Accuracy:     0.6741
#   Precision:    0.4816
#   Recall:       0.7844
#   F1:           0.5968
#
# Test Results (Threshold = 0.80):
#   Accuracy:     0.7934
#   Precision:    0.7031
#   Recall:       0.5676
#   F1:           0.6282
#
# Output Files:
#   Model:    /content/drive/MyDrive/MULTIMODAL/models/efficientnet_b3_experiment/efficientnet_b3_binary_dr_twostage.pth
#   Figures:  /content/drive/MyDrive/MULTIMODAL/models/efficientnet_b3_experiment/figures/
#
# ─────────────────────────────────────────────────
#
#
# ======================================================================
# HELPER CODE FOR LOADING MODEL
# ======================================================================
#
# # Load trained EfficientNet-B3 model for multimodal fusion:
#
# import torch
# import torch.nn as nn
# from torchvision import models
#
# class BinaryDRClassifier(nn.Module):
#     def __init__(self, model_name='efficientnet_b3', pretrained=False, dropout=0.3):
#         super().__init__()
#         self.backbone = models.efficientnet_b3(weights=None)
#         n = self.backbone.classifier[1].in_features
#         self.backbone.classifier = nn.Identity()
#         self.feature_dim = n  # 1536 for B3
#         self.classifier = nn.Sequential(
#             nn.Dropout(dropout),
#             nn.Linear(n, 256),
#             nn.ReLU(),
#             nn.BatchNorm1d(256),
#             nn.Dropout(dropout * 0.5),
#             nn.Linear(256, 1)
#         )
#
#     def extract_features(self, x):
#         return self.backbone(x)
#
#     def forward(self, x):
#         f = self.backbone(x)
#         return self.classifier(f)
#
# def load_retinal_model(checkpoint_path, device='cpu'):
#     checkpoint = torch.load(checkpoint_path, map_location=device)
#     config = checkpoint.get('config', {})
#
#     model = BinaryDRClassifier(
#         model_name=config.get('model_name', 'efficientnet_b3'),
#         pretrained=False,
#         dropout=config.get('dropout', 0.3)
#     )
#     model.load_state_dict(checkpoint['model_state_dict'])
#     model.to(device)
#     model.eval()
#
#     return model, checkpoint
#
# # Usage:
# # model, checkpoint = load_retinal_model('efficientnet_b3_binary_dr_twostage.pth')
# # optimal_threshold = checkpoint['optimal_threshold']
# # features = model.extract_features(images)  # Shape: (B, 1536)
#
#
# ======================================================================
# ✓ PIPELINE COMPLETE
# ======================================================================
